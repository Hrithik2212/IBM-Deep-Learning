# %% [markdown]
# # Machine Learning Foundation
#
# ## Course 5, Part c: Backpropagation DEMO

# %% [markdown]
# ## Overview
# In this exercise we will use backpropagation to train a multi-layer perceptron (with a single hidden layer).  We will experiment with different patterns and see how quickly or slowly the weights converge.  We will see the impact and interplay of different parameters such as learning rate, number of iterations, and number of data points.

# %%
#Setup
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this exercise, we will prepare code to create a multi-layer perceptron with a single hidden layer (with 4 nodes) and train it via back-propagation.  We will take the following steps:
#
# 1. Initialize the weights to random values between -1 and 1
# 1. Perform the feed-forward computation
# 1. Compute the loss function
# 1. Calculate the gradients for all the weights via back-propagation
# 1. Update the weight matrices (using a learning_rate parameter)
# 1. Execute steps 2-5 for a fixed number of iterations
# 1. Plot the accuracies and log loss and observe how they change over time
#
#
# Once the code is running, we can address the following questions:
# - Which patterns was the neural network able to learn quickly and which took longer?
# - What learning rates and numbers of iterations worked well?
# - If you have time, try varying the size of the hidden layer and experiment with different activation functions (e.g. ReLu)

# %%
## This code below generates two x values and a y value according to different patterns
## It also creates a "bias" term (a vector of 1s)
## The goal is then to learn the mapping from x to y using a neural network via back-propagation

num_obs = 500
x_mat_1 = np.random.uniform(-1,1,size = (num_obs,2))
x_mat_bias = np.ones((num_obs,1))
x_mat_full = np.concatenate( (x_mat_1,x_mat_bias), axis=1)

# PICK ONE PATTERN BELOW and comment out the rest.

# # Circle pattern
# y = (np.sqrt(x_mat_full[:,0]**2 + x_mat_full[:,1]**2)<.75).astype(int)

# # Diamond Pattern
y = ((np.abs(x_mat_full[:,0]) + np.abs(x_mat_full[:,1]))<1).astype(int)

# # Centered square
# y = ((np.maximum(np.abs(x_mat_full[:,0]), np.abs(x_mat_full[:,1])))<.5).astype(int)

# # Thick Right Angle pattern
# y = (((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))<.5) & ((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))>-.5)).astype(int)

# # Thin right angle pattern
# y = (((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))<.5) & ((np.maximum((x_mat_full[:,0]), (x_mat_full[:,1])))>0)).astype(int)


print('shape of x_mat_full is {}'.format(x_mat_full.shape))
print('shape of y is {}'.format(y.shape))

fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')
# ax.grid(True)
ax.legend(loc='best')
ax.axis('equal');
# Out:
# shape of x_mat_full is (500, 3)
# shape of y is (500,)
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_27564/309342056.py:32: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_27564/309342056.py:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bx" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')

# %% [markdown]
# Here are some helper functions

# %%
def sigmoid(x):
    """
    Sigmoid function
    """
    return 1.0 / (1.0 + np.exp(-x))


def loss_fn(y_true, y_pred, eps=1e-16):
    """
    Loss function we would like to optimize (minimize)
    We are using Logarithmic Loss
    http://scikit-learn.org/stable/modules/model_evaluation.html#log-loss
    """
    y_pred = np.maximum(y_pred,eps)
    y_pred = np.minimum(y_pred,(1-eps))
    return -(np.sum(y_true * np.log(y_pred)) + np.sum((1-y_true)*np.log(1-y_pred)))/len(y_true)


def forward_pass(W1, W2):
    """
    Does a forward computation of the neural network
    Takes the input `x_mat` (global variable) and produces the output `y_pred`
    Also produces the gradient of the log loss function
    """
    global x_mat
    global y
    global num_
    # First, compute the new predictions `y_pred`
    z_2 = np.dot(x_mat, W_1)
    a_2 = sigmoid(z_2)
    z_3 = np.dot(a_2, W_2)
    y_pred = sigmoid(z_3).reshape((len(x_mat),))
    # Now compute the gradient
    J_z_3_grad = -y + y_pred
    J_W_2_grad = np.dot(J_z_3_grad, a_2)
    a_2_z_2_grad = sigmoid(z_2)*(1-sigmoid(z_2))
    J_W_1_grad = (np.dot((J_z_3_grad).reshape(-1,1), W_2.reshape(-1,1).T)*a_2_z_2_grad).T.dot(x_mat).T
    gradient = (J_W_1_grad, J_W_2_grad)
    
    # return
    return y_pred, gradient


def plot_loss_accuracy(loss_vals, accuracies):
    fig = plt.figure(figsize=(16, 8))
    fig.suptitle('Log Loss and Accuracy over iterations')
    
    ax = fig.add_subplot(1, 2, 1)
    ax.plot(loss_vals)
    ax.grid(True)
    ax.set(xlabel='iterations', title='Log Loss')
    
    ax = fig.add_subplot(1, 2, 2)
    ax.plot(accuracies)
    ax.grid(True)
    ax.set(xlabel='iterations', title='Accuracy');

# %%
#### Initialize the network parameters

np.random.seed(1241)

W_1 = np.random.uniform(-1,1,size=(3,4))
W_2 = np.random.uniform(-1,1,size=(4))
num_iter = 10001
learning_rate = .001
x_mat = x_mat_full


loss_vals, accuracies = [], []
for i in range(num_iter):
    ### Do a forward computation, and get the gradient
    y_pred, (J_W_1_grad, J_W_2_grad) = forward_pass(W_1, W_2)
    
    ## Update the weight matrices
    W_1 = W_1 - learning_rate*J_W_1_grad 
    W_2 = W_2 - learning_rate*J_W_2_grad
    
    ### Compute the loss and accuracy
    curr_loss = loss_fn(y,y_pred)
    loss_vals.append(curr_loss)
    acc = np.sum((y_pred>=.5) == y)/num_obs
    accuracies.append(acc)

    ## Print the loss and accuracy for every 200th iteration
    if((i%200) == 0):
        print('iteration {}, log loss is {:.4f}, accuracy is {}'.format(
            i, curr_loss, acc
        ))
plot_loss_accuracy(loss_vals, accuracies)
# Out:
# iteration 0, log loss is 0.8464, accuracy is 0.468
# iteration 200, log loss is 0.6838, accuracy is 0.638
# iteration 400, log loss is 0.6607, accuracy is 0.664
# iteration 600, log loss is 0.5801, accuracy is 0.74
# iteration 800, log loss is 0.5026, accuracy is 0.774
# iteration 1000, log loss is 0.4752, accuracy is 0.77
# iteration 1200, log loss is 0.4673, accuracy is 0.768
# iteration 1400, log loss is 0.4647, accuracy is 0.77
# iteration 1600, log loss is 0.4636, accuracy is 0.772
# iteration 1800, log loss is 0.4623, accuracy is 0.772
# iteration 2000, log loss is 0.4585, accuracy is 0.774
# iteration 2200, log loss is 0.4407, accuracy is 0.782
# iteration 2400, log loss is 0.3907, accuracy is 0.812
# iteration 2600, log loss is 0.3311, accuracy is 0.872
# iteration 2800, log loss is 0.2873, accuracy is 0.922
# iteration 3000, log loss is 0.2534, accuracy is 0.938
# iteration 3200, log loss is 0.2242, accuracy is 0.948
# iteration 3400, log loss is 0.2019, accuracy is 0.96
# iteration 3600, log loss is 0.1857, accuracy is 0.966
# iteration 3800, log loss is 0.1738, accuracy is 0.968
# iteration 4000, log loss is 0.1647, accuracy is 0.972
# iteration 4200, log loss is 0.1575, accuracy is 0.982
# iteration 4400, log loss is 0.1515, accuracy is 0.984
# iteration 4600, log loss is 0.1464, accuracy is 0.986
# iteration 4800, log loss is 0.1420, accuracy is 0.986
# iteration 5000, log loss is 0.1382, accuracy is 0.984
# iteration 5200, log loss is 0.1348, accuracy is 0.984
# iteration 5400, log loss is 0.1318, accuracy is 0.984
# iteration 5600, log loss is 0.1291, accuracy is 0.986
# iteration 5800, log loss is 0.1267, accuracy is 0.986
# iteration 6000, log loss is 0.1245, accuracy is 0.988
# iteration 6200, log loss is 0.1226, accuracy is 0.988
# iteration 6400, log loss is 0.1207, accuracy is 0.988
# iteration 6600, log loss is 0.1190, accuracy is 0.988
# iteration 6800, log loss is 0.1175, accuracy is 0.988
# iteration 7000, log loss is 0.1160, accuracy is 0.988
# iteration 7200, log loss is 0.1146, accuracy is 0.988
# iteration 7400, log loss is 0.1133, accuracy is 0.988
# iteration 7600, log loss is 0.1121, accuracy is 0.988
# iteration 7800, log loss is 0.1109, accuracy is 0.988
# iteration 8000, log loss is 0.1098, accuracy is 0.988
# iteration 8200, log loss is 0.1087, accuracy is 0.988
# iteration 8400, log loss is 0.1077, accuracy is 0.988
# iteration 8600, log loss is 0.1068, accuracy is 0.988
# iteration 8800, log loss is 0.1058, accuracy is 0.988
# iteration 9000, log loss is 0.1049, accuracy is 0.988
# iteration 9200, log loss is 0.1041, accuracy is 0.988
# iteration 9400, log loss is 0.1032, accuracy is 0.988
# iteration 9600, log loss is 0.1024, accuracy is 0.988
# iteration 9800, log loss is 0.1017, accuracy is 0.988
# iteration 10000, log loss is 0.1009, accuracy is 0.988

# %% [markdown]
# Plot the predicted answers, with mistakes in yellow

# %%
pred1 = (y_pred>=.5)
pred0 = (y_pred<.5)

fig, ax = plt.subplots(figsize=(8, 8))
# true predictions
ax.plot(x_mat[pred1 & (y==1),0],x_mat[pred1 & (y==1),1], 'ro', label='true positives')
ax.plot(x_mat[pred0 & (y==0),0],x_mat[pred0 & (y==0),1], 'bx', label='true negatives')
# false predictions
ax.plot(x_mat[pred1 & (y==0),0],x_mat[pred1 & (y==0),1], 'yx', label='false positives', markersize=15)
ax.plot(x_mat[pred0 & (y==1),0],x_mat[pred0 & (y==1),1], 'yo', label='false negatives', markersize=15, alpha=.6)
ax.set(title='Truth vs Prediction')
ax.legend(bbox_to_anchor=(1, 0.8), fancybox=True, shadow=True, fontsize='x-large');

# %% [markdown]
# ---
# ### Machine Learning Foundation (C) 2020 IBM Corporation

# %%
# # Centered square
y = ((np.maximum(np.abs(x_mat_full[:,0]), np.abs(x_mat_full[:,1])))<.5).astype(int)

fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')
# ax.grid(True)
ax.legend(loc='best')
ax.axis('equal');
# Out:
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_27564/1457937304.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_27564/1457937304.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bx" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')

# %%
W_1 = np.random.uniform(-1,1,size=(3,4))
W_2 = np.random.uniform(-1,1,size=(4))
num_iter = 10001
learning_rate = .001
x_mat = x_mat_full


loss_vals, accuracies = [], []
for i in range(num_iter):
    ### Do a forward computation, and get the gradient
    y_pred, (J_W_1_grad, J_W_2_grad) = forward_pass(W_1, W_2)
    
    ## Update the weight matrices
    W_1 = W_1 - learning_rate*J_W_1_grad 
    W_2 = W_2 - learning_rate*J_W_2_grad
    
    ### Compute the loss and accuracy
    curr_loss = loss_fn(y,y_pred)
    loss_vals.append(curr_loss)
    acc = np.sum((y_pred>=.5) == y)/num_obs
    accuracies.append(acc)

    ## Print the loss and accuracy for every 200th iteration
    if((i%200) == 0):
        print('iteration {}, log loss is {:.4f}, accuracy is {}'.format(
            i, curr_loss, acc
        ))
plot_loss_accuracy(loss_vals, accuracies)
# Out:
# iteration 0, log loss is 0.7810, accuracy is 0.406
# iteration 200, log loss is 0.6068, accuracy is 0.704
# iteration 400, log loss is 0.6055, accuracy is 0.704
# iteration 600, log loss is 0.6040, accuracy is 0.704
# iteration 800, log loss is 0.6006, accuracy is 0.704
# iteration 1000, log loss is 0.5925, accuracy is 0.704
# iteration 1200, log loss is 0.5791, accuracy is 0.704
# iteration 1400, log loss is 0.5618, accuracy is 0.704
# iteration 1600, log loss is 0.5347, accuracy is 0.704
# iteration 1800, log loss is 0.4897, accuracy is 0.704
# iteration 2000, log loss is 0.4291, accuracy is 0.804
# iteration 2200, log loss is 0.3435, accuracy is 0.886
# iteration 2400, log loss is 0.2674, accuracy is 0.926
# iteration 2600, log loss is 0.2240, accuracy is 0.942
# iteration 2800, log loss is 0.1983, accuracy is 0.938
# iteration 3000, log loss is 0.1813, accuracy is 0.944
# iteration 3200, log loss is 0.1696, accuracy is 0.946
# iteration 3400, log loss is 0.1613, accuracy is 0.944
# iteration 3600, log loss is 0.1551, accuracy is 0.944
# iteration 3800, log loss is 0.1502, accuracy is 0.946
# iteration 4000, log loss is 0.1463, accuracy is 0.944
# iteration 4200, log loss is 0.1428, accuracy is 0.944
# iteration 4400, log loss is 0.1398, accuracy is 0.944
# iteration 4600, log loss is 0.1370, accuracy is 0.946
# iteration 4800, log loss is 0.1344, accuracy is 0.944
# iteration 5000, log loss is 0.1320, accuracy is 0.944
# iteration 5200, log loss is 0.1297, accuracy is 0.946
# iteration 5400, log loss is 0.1276, accuracy is 0.946
# iteration 5600, log loss is 0.1257, accuracy is 0.946
# iteration 5800, log loss is 0.1238, accuracy is 0.95
# iteration 6000, log loss is 0.1221, accuracy is 0.95
# iteration 6200, log loss is 0.1205, accuracy is 0.95
# iteration 6400, log loss is 0.1189, accuracy is 0.95
# iteration 6600, log loss is 0.1175, accuracy is 0.95
# iteration 6800, log loss is 0.1162, accuracy is 0.95
# iteration 7000, log loss is 0.1149, accuracy is 0.95
# iteration 7200, log loss is 0.1137, accuracy is 0.952
# iteration 7400, log loss is 0.1125, accuracy is 0.952
# iteration 7600, log loss is 0.1114, accuracy is 0.952
# iteration 7800, log loss is 0.1103, accuracy is 0.952
# iteration 8000, log loss is 0.1093, accuracy is 0.954
# iteration 8200, log loss is 0.1084, accuracy is 0.954
# iteration 8400, log loss is 0.1075, accuracy is 0.954
# iteration 8600, log loss is 0.1066, accuracy is 0.954
# iteration 8800, log loss is 0.1058, accuracy is 0.954
# iteration 9000, log loss is 0.1050, accuracy is 0.958
# iteration 9200, log loss is 0.1042, accuracy is 0.958
# iteration 9400, log loss is 0.1035, accuracy is 0.958
# iteration 9600, log loss is 0.1028, accuracy is 0.958
# iteration 9800, log loss is 0.1021, accuracy is 0.958
# iteration 10000, log loss is 0.1015, accuracy is 0.958

# %%
pred1 = (y_pred>=.5)
pred0 = (y_pred<.5)

fig, ax = plt.subplots(figsize=(8, 8))
# true predictions
ax.plot(x_mat[pred1 & (y==1),0],x_mat[pred1 & (y==1),1], 'ro', label='true positives')
ax.plot(x_mat[pred0 & (y==0),0],x_mat[pred0 & (y==0),1], 'bx', label='true negatives')
# false predictions
ax.plot(x_mat[pred1 & (y==0),0],x_mat[pred1 & (y==0),1], 'yx', label='false positives', markersize=15)
ax.plot(x_mat[pred0 & (y==1),0],x_mat[pred0 & (y==1),1], 'yo', label='false negatives', markersize=15, alpha=.6)
ax.set(title='Truth vs Prediction')
ax.legend(bbox_to_anchor=(1, 0.8), fancybox=True, shadow=True, fontsize='x-large');

# %% [markdown]
# ---

# %%
# # Circle pattern
y = (np.sqrt(x_mat_full[:,0]**2 + x_mat_full[:,1]**2)<.75).astype(int)
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')
# ax.grid(True)
ax.legend(loc='best')
ax.axis('equal');
W_1 = np.random.uniform(-1,1,size=(3,4))
W_2 = np.random.uniform(-1,1,size=(4))
num_iter = 10001
learning_rate = .001
x_mat = x_mat_full


loss_vals, accuracies = [], []
for i in range(num_iter):
    ### Do a forward computation, and get the gradient
    y_pred, (J_W_1_grad, J_W_2_grad) = forward_pass(W_1, W_2)
    
    ## Update the weight matrices
    W_1 = W_1 - learning_rate*J_W_1_grad 
    W_2 = W_2 - learning_rate*J_W_2_grad
    
    ### Compute the loss and accuracy
    curr_loss = loss_fn(y,y_pred)
    loss_vals.append(curr_loss)
    acc = np.sum((y_pred>=.5) == y)/num_obs
    accuracies.append(acc)

    ## Print the loss and accuracy for every 200th iteration
    if((i%200) == 0):
        print('iteration {}, log loss is {:.4f}, accuracy is {}'.format(
            i, curr_loss, acc
        ))
plot_loss_accuracy(loss_vals, accuracies)
pred1 = (y_pred>=.5)
pred0 = (y_pred<.5)

fig, ax = plt.subplots(figsize=(8, 8))
# true predictions
ax.plot(x_mat[pred1 & (y==1),0],x_mat[pred1 & (y==1),1], 'ro', label='true positives')
ax.plot(x_mat[pred0 & (y==0),0],x_mat[pred0 & (y==0),1], 'bx', label='true negatives')
# false predictions
ax.plot(x_mat[pred1 & (y==0),0],x_mat[pred1 & (y==0),1], 'yx', label='false positives', markersize=15)
ax.plot(x_mat[pred0 & (y==1),0],x_mat[pred0 & (y==1),1], 'yo', label='false negatives', markersize=15, alpha=.6)
ax.set(title='Truth vs Prediction')
ax.legend(bbox_to_anchor=(1, 0.8), fancybox=True, shadow=True, fontsize='x-large');
# Out:
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_27564/581932757.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(x_mat_full[y==1, 0],x_mat_full[y==1, 1], 'ro', label='class 1', color='darkslateblue')
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_27564/581932757.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bx" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(x_mat_full[y==0, 0],x_mat_full[y==0, 1], 'bx', label='class 0', color='chocolate')
# iteration 0, log loss is 0.7056, accuracy is 0.518
# iteration 200, log loss is 0.6870, accuracy is 0.494
# iteration 400, log loss is 0.6781, accuracy is 0.536
# iteration 600, log loss is 0.6608, accuracy is 0.56
# iteration 800, log loss is 0.6293, accuracy is 0.704
# iteration 1000, log loss is 0.5728, accuracy is 0.766
# iteration 1200, log loss is 0.5073, accuracy is 0.764
# iteration 1400, log loss is 0.4789, accuracy is 0.78
# iteration 1600, log loss is 0.4682, accuracy is 0.778
# iteration 1800, log loss is 0.4622, accuracy is 0.78
# iteration 2000, log loss is 0.4572, accuracy is 0.782
# iteration 2200, log loss is 0.4470, accuracy is 0.788
# iteration 2400, log loss is 0.3872, accuracy is 0.818
# iteration 2600, log loss is 0.2918, accuracy is 0.928
# iteration 2800, log loss is 0.2452, accuracy is 0.932
# iteration 3000, log loss is 0.2229, accuracy is 0.926
# iteration 3200, log loss is 0.2095, accuracy is 0.93
# iteration 3400, log loss is 0.2002, accuracy is 0.928
# iteration 3600, log loss is 0.1930, accuracy is 0.934
# iteration 3800, log loss is 0.1871, accuracy is 0.934
# iteration 4000, log loss is 0.1820, accuracy is 0.938
# iteration 4200, log loss is 0.1775, accuracy is 0.94
# iteration 4400, log loss is 0.1734, accuracy is 0.94
# iteration 4600, log loss is 0.1697, accuracy is 0.94
# iteration 4800, log loss is 0.1662, accuracy is 0.946
# iteration 5000, log loss is 0.1630, accuracy is 0.948
# iteration 5200, log loss is 0.1600, accuracy is 0.948
# iteration 5400, log loss is 0.1572, accuracy is 0.95
# iteration 5600, log loss is 0.1546, accuracy is 0.95
# iteration 5800, log loss is 0.1521, accuracy is 0.952
# iteration 6000, log loss is 0.1498, accuracy is 0.954
# iteration 6200, log loss is 0.1475, accuracy is 0.956
# iteration 6400, log loss is 0.1454, accuracy is 0.956
# iteration 6600, log loss is 0.1434, accuracy is 0.958
# iteration 6800, log loss is 0.1415, accuracy is 0.958
# iteration 7000, log loss is 0.1396, accuracy is 0.958
# iteration 7200, log loss is 0.1379, accuracy is 0.958
# iteration 7400, log loss is 0.1362, accuracy is 0.958
# iteration 7600, log loss is 0.1346, accuracy is 0.96
# iteration 7800, log loss is 0.1330, accuracy is 0.96
# iteration 8000, log loss is 0.1316, accuracy is 0.96
# iteration 8200, log loss is 0.1301, accuracy is 0.962
# iteration 8400, log loss is 0.1288, accuracy is 0.962
# iteration 8600, log loss is 0.1274, accuracy is 0.962
# iteration 8800, log loss is 0.1261, accuracy is 0.962
# iteration 9000, log loss is 0.1249, accuracy is 0.962
# iteration 9200, log loss is 0.1237, accuracy is 0.964
# iteration 9400, log loss is 0.1225, accuracy is 0.966
# iteration 9600, log loss is 0.1214, accuracy is 0.966
# iteration 9800, log loss is 0.1203, accuracy is 0.966
# iteration 10000, log loss is 0.1193, accuracy is 0.966

# %% [markdown]
# ---
